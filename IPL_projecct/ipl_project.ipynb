# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We use above data set of bowlers and batesman excluding the alrounders because of not having the data for the alrounders so we concatinate the data of bowlers and batsman differngly because they both having the different components to show

# %%
data=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2016.csv")
data1=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2017.csv")
data2=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2018.csv")
data3=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2019.csv")
data4=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2020.csv")
data5=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2021.csv")
data6=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2022.csv")
data7=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2016.csv")
data8=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2017.csv")
data9=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2018.csv")
data10=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2019.csv")
data11=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2020.csv")
data12=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2021.csv")
data13=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\IPL_projecct\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2022.csv")

# %% [markdown]
# We use above data set of bowlers and batesman excluding the alrounders because of not having the data for the alrounders so we concatinate the data of bowlers and batsman differngly because they both having the different components to show

# %%
ipl_batting=pd.concat([data,data1,data2,data3,data4,data5,data6])
ipl_bowler=pd.concat([data7,data8,data9,data10,data11,data12,data13])

# %%
ipl_batting.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
ipl_bowler.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# Ov        0
# Runs      0
# Wkts      0
# BBI       0
# Avg       0
# Econ      0
# SR        0
# 4w        0
# 5w        0
# dtype: int64

# %% [markdown]
# We pick 13 batter and 12 bowlers

# %% [markdown]
# First of all we find best  batting stats in ipl

# %%
combined_data=pd.DataFrame()

# %%
#filter the data
batting_data=ipl_batting[['Player','Runs']]

# %%
batting_status=batting_data.groupby('Player').agg({'Runs':'sum'})

# %%
combined_data=combined_data.append(batting_data)
# Out:
# C:\Users\91785\AppData\Local\Temp\ipykernel_1580\1011591193.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data=combined_data.append(batting_data)

# %%
batter_runs=combined_data.groupby('Player')['Runs'].sum()

# %%
top_batter=batter_runs.nlargest(13)

# %%
top_batter
# Out:
# Player
# Shikhar Dhawan      3663
# Virat Kohli         3487
# David Warner        3356
# KL Rahul            2945
# Rishabh Pant        2838
# Jos Buttler         2831
# Sanju Samson        2777
# AB de Villiers      2592
# Rohit Sharma        2494
# Shreyas Iyer        2337
# Suryakumar Yadav    2323
# Ambati Rayudu       2199
# Nitish Rana         2181
# Name: Runs, dtype: int64

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Shikhar Dhawan']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Virat Kohli']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['David Warner']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['KL Rahul']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Rishabh Pant']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Jos Buttler']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Sanju Samson']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['AB de Villiers']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Rohit Sharma']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Shreyas Iyer']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Suryakumar Yadav']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Ambati Rayudu']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Nitish Rana']
plt.plot(trend.index)

# %% [markdown]
# Bowling

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Jasprit Bumrah']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Yuzvendra Chahal']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Rashid Khan']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Kagiso Rabada']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Bhuvneshwar Kumar']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Mohammad Shami']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Trent Boult']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Shardul Thakur']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Dwayne Bravo']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Sunil Narine']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Sandeep Sharma']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipl_bowler[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Andre Russell']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)
